# %%
# import requests
# from bs4 import BeautifulSoup
# from selenium import webdriver
# from selenium.webdriver.chrome.service import Service
# from selenium.webdriver.chrome.options import Options
# from selenium.webdriver.support.ui import WebDriverWait
# import numpy as np
# import pandas as pd
# import re
# from time import sleep
# from selenium.webdriver.common.action_chains import ActionChains
import transfermarkt

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
# 実験用
# 選手の情報が入っているテーブル
table = soup.select("#yw1 > table")[0]

# テーブルの中の選手情報
table_body = table.find("tbody")

players_tr_tags = table_body.find_all("tr", recursive=False)
# player_info_lis = player_info_tag.find_all("td", recursive=False)
players_tr_tags[0].find_all("td", recursive=False)[-1].find("i")
#player_info_lis = player_info_tag.find_all("td", recursive=False)

# %%
transfer_url = "https://www.transfermarkt.com"
url = "https://www.transfermarkt.com/j2-league/transferrekorde/wettbewerb/JAP2/saison_id/alle/land_id//ausrichtung//spielerposition_id//altersklasse//leihe//w_s//zuab/0/plus/1"
headers = {"User-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36 Edg/92.0.902.84"}

# データを格納するデータフレームを作成
#col_names = ["Name", "Position", "Age", "Season", "Player_nat", "Left_team", "Left_league", "Left_team_nat", "Joined_team", "Joined_league", "Joined_nat", "Fee", "Face_img"]
#transfer_df = pd.DataFrame(np.zeros((0, 13)), columns=col_names)

# 次のページへ遷移するボタンが存在する限り繰り返す

output_df = scrayping_this_league(url, headers=headers)

# %%
output_df
# Out:
#                  Name            Position Age Season            Player_nat  \
# 0                Hulk      Centre-Forward  22  08/09                Brazil
# 0         Diego Souza  Attacking Midfield  24  08/09                Brazil
# 0            Reinaldo      Centre-Forward  26  05/06                Brazil
# 0             Douglas      Centre-Forward  28  15/16                Brazil
# 0      Michael Olunga      Centre-Forward  24  18/19                 Kenya
# 0            Leonardo      Centre-Forward  22  19/20                Brazil
# 0              França      Centre-Forward  29  05/06       Brazil/Portugal
# 0        Daniel Rossi  Defensive Midfield  20  01/02                Brazil
# 0                Davi      Centre-Forward  24  08/09                Brazil
# 0    Gerson Rodrigues         Left Winger  24  19/20   Luxembourg/Portugal
# 0              Borges      Centre-Forward  25  05/06                Brazil
# ...

# %%
print(country_url)
# Out:
# https://www.transfermarkt.com/wettbewerbe/national/wettbewerbe/77

# %%
all_competetion = country_all_competetion("Japan")

# %%
driver = webdriver.Chrome("C:/Users/yoshi/webdriver/chromedriver_win32/chromedriver.exe")
transfer_url = "https://www.transfermarkt.com" # トップページのURL
country_name = "Japan"
#competition_name = "J1 League"
driver.get(transfer_url)
# フルスクリーンで表示　画面スクロールの値に影響してくる
driver.maximize_window()


#all_competetion = country_all_competetion("Japan")

for i, competition in enumerate(all_competetion):
    print(competition)
    if i == 0:
        detail_url = guide_from_country_and_league_to_leagueurl(country_name, competition)
    else:
        detail_url = guide_from_country_and_league_to_leagueurl(country_name, competition, same_country=True)
    #print(competetion)
    #print(detail_url)
# Out:
# J1 League
# J2 League
# J3 League
# Japan Football League
# Hokkaido Soccer League
# Tohoku Soccer League (Div.1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-189-5018dc625a71> in <module>
#      15         detail_url = guide_from_country_and_league_to_leagueurl(country_name, competition)
#      16     else:
# ---> 17         detail_url = guide_from_country_and_league_to_leagueurl(country_name, competition, same_country=True)
#      18     #print(competetion)
#      19     #print(detail_url)
#
# <ipython-input-188-f623c0a4c6aa> in guide_from_country_and_league_to_leagueurl(country_name, competition_name, same_country)
#     193     driver.implicitly_wait(20)
#     194     # そのリーグのTransfer Recordをクリック
# --> 195     transfer_record_elem = driver.find_element_by_xpath('//*[@id="transfers"]/div/div/div[1]/ul/li[7]/a')
#     196     sleep(2)
# ...

# %%
from selenium import webdriver
import transfermarkt
headers = {"User-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36 Edg/92.0.902.84"}
driver = webdriver.Chrome("C:/Users/yoshi/webdriver/chromedriver_win32/chromedriver.exe")

tf = TransferMarkt(driver, headers=headers)

# %%
# search_competition
# make_empty_df
tf.search_competition("Japan")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-6751a9748edd> in <module>
#       1 # search_competition
#       2 # make_empty_df
# ----> 3 tf.search_competition("Japan")
#
# <ipython-input-42-15e4375fce2d> in search_competition(self, country_name)
#     272     def search_competition(self, country_name):
#     273         # shadow-DOMを開く
# --> 274         shadow_root_bar = open_shadow_DOM()
#     275
#     276         self.fill_in_country(country_name, shadow_root_bar)
#
# NameError: name 'open_shadow_DOM' is not defined
